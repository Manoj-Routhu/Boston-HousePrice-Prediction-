# %%
import numpy as np
import pandas as pd
import os
os.chdir("C:\\Users\\admin\\Desktop\\code\\house price prediction")
first = pd.read_csv("train.csv")
second = pd.read_csv("test.csv")

# %%
pd.DataFrame(first)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pd.DataFrame(second)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
second['BsmtUnfSF']
# Out:
# 0        270.0
# 1        406.0
# 2        137.0
# 3        324.0
# 4       1017.0
#          ...
# 1454     546.0
# 1455     294.0
# 1456       0.0
# 1457     575.0
# 1458     238.0
# Name: BsmtUnfSF, Length: 1459, dtype: float64

# %%
print(first.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 66 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   int64
#  5   LandContour    1460 non-null   int64
#  6   LotConfig      1460 non-null   float64
#  7   LandSlope      1460 non-null   int64
#  8   Neighborhood   1460 non-null   float64
#  9   Condition1     1460 non-null   int64
#  10  Condition2     1460 non-null   float64
#  11  BldgType       1460 non-null   int64
#  12  HouseStyle     1460 non-null   int64
#  13  OverallQual    1460 non-null   int64
#  14  OverallCond    1460 non-null   int64
#  15  YearBuilt      1460 non-null   int64
#  16  YearRemodAdd   1460 non-null   int64
#  17  RoofStyle      1460 non-null   int64
# ...

# %%
print(second.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   int64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   int64
#  5   LandContour    1459 non-null   int64
#  6   LotConfig      1459 non-null   float64
#  7   LandSlope      1459 non-null   int64
#  8   Neighborhood   1459 non-null   float64
#  9   Condition1     1459 non-null   int64
#  10  Condition2     1459 non-null   int64
#  11  BldgType       1459 non-null   int64
#  12  HouseStyle     1459 non-null   int64
#  13  OverallQual    1459 non-null   int64
#  14  OverallCond    1459 non-null   int64
#  15  YearBuilt      1459 non-null   int64
#  16  YearRemodAdd   1459 non-null   int64
#  17  RoofStyle      1459 non-null   int64
# ...

# %%
second.BsmtUnfSF.value_counts()
# Out:
# 0.0       123
# 384.0      11
# 624.0       8
# 738.0       7
# 100.0       7
#          ...
# 36.0        1
# 892.0       1
# 747.0       1
# 1216.0      1
# 1503.0      1
# Name: BsmtUnfSF, Length: 793, dtype: int64

# %%
first['BsmtFinType1'] = pd.to_numeric(first['BsmtFinType1'], errors='coerce')

# %%
mean_value=first['LotConfig'].mean()
first['LotConfig'].fillna(value=mean_value, inplace=True)

# %%
first['Neighborhood'].fillna(first['Neighborhood'].mode()[0], inplace=True)
first['Condition2'].fillna(first['Condition2'].mode()[0], inplace=True)
first['Exterior1st'].fillna(first['Exterior1st'].mode()[0], inplace=True)

# %%
second['MSZoning'].fillna(second['MSZoning'].mode()[0], inplace=True)
second['LotConfig'].fillna(second['LotConfig'].mode()[0], inplace=True)
second['Neighborhood'].fillna(second['Neighborhood'].mode()[0], inplace=True)
second['Exterior1st'].fillna(second['Exterior1st'].mode()[0], inplace=True)
second['Exterior2nd'].fillna(second['Exterior2nd'].mode()[0], inplace=True)
second['BsmtFinType1'].fillna(second['BsmtFinType1'].mode()[0], inplace=True)
second['BsmtFinSF2'].fillna(second['BsmtFinSF2'].mode()[0], inplace = True)
second['TotalBsmtSF'].fillna(second['TotalBsmtSF'].mode()[0], inplace = True)
second['BsmtUnfSF'].fillna(second['BsmtUnfSF'].mode()[0], inplace = True)
second['BsmtFullBath'].fillna(second['BsmtFullBath'].mode()[0], inplace = True)
second['BsmtHalfBath'].fillna(second['BsmtHalfBath'].mode()[0], inplace = True)
second['KitchenQual'].fillna(second['KitchenQual'].mode()[0], inplace = True)
second['Functional'].fillna(second['Functional'].mode()[0], inplace = True)
second['GarageCars'].fillna(second['GarageCars'].mode()[0], inplace = True)
second['GarageArea'].fillna(second['GarageArea'].mode()[0], inplace = True)
second['SaleType'].fillna(second['SaleType'].mode()[0], inplace = True)

# %%
x = first["Exterior1st"].mode()[0]

first["Exterior1st"].fillna(x, inplace = True)

# %%
first.drop(['Alley','Utilities','GarageType','LotShape','MasVnrArea','GarageFinish','GarageYrBlt','PoolArea','PoolQC','Fence','MiscFeature','GarageCond','GarageQual','FireplaceQu','LotFrontage'],inplace=True,axis=1)

# %%
second.drop(['Alley','Utilities','GarageType','LotShape','MasVnrArea','GarageFinish','GarageYrBlt','PoolArea','PoolQC','Fence','MiscFeature','GarageCond','GarageQual','FireplaceQu','LotFrontage'],inplace=True,axis=1)

# %%
data=[first]
for dataset in data:
    dataset.BsmtQual=dataset.BsmtQual.fillna('TA')
    dataset.MasVnrType=dataset.MasVnrType.fillna('None')
    dataset.BsmtCond=dataset.BsmtCond.fillna('TA')
    dataset.BsmtExposure=dataset.BsmtExposure.fillna('No')
    dataset.BsmtFinType1=dataset.BsmtFinType1.fillna('Unf')
    dataset.BsmtFinType2=dataset.BsmtFinType2.fillna('Unf')
    dataset.LotConfig=dataset.LotConfig.fillna(0.0)
    dataset.Neighborhood=dataset.Neighborhood.fillna(0.0)
    dataset.Electrical=dataset.Electrical.fillna('SBrkr')
    dataset.Condition2=dataset.Condition2.fillna(0.0)

# %%
data=[second]
for dataset in data:
    dataset.BsmtQual=dataset.BsmtQual.fillna('TA')
    dataset.MasVnrType=dataset.MasVnrType.fillna('None')
    dataset.BsmtCond=dataset.BsmtCond.fillna('TA')
    dataset.BsmtExposure=dataset.BsmtExposure.fillna('No')
    dataset.BsmtFinType1=dataset.BsmtFinType1.fillna('Unf')
    dataset.BsmtFinType2=dataset.BsmtFinType2.fillna('Unf')
    dataset.LotConfig=dataset.LotConfig.fillna(0.0)
    dataset.Neighborhood=dataset.Neighborhood.fillna(0.0)
    dataset.Electrical=dataset.Electrical.fillna('SBrkr')
    dataset.Condition2=dataset.Condition2.fillna(0.0)
    dataset.MSZoning=dataset.MSZoning.fillna(0.0)
    dataset.Exterior1st=dataset.Exterior1st.fillna(0.0)
    dataset.Exterior2nd=dataset.Exterior2nd.fillna(0.0)
    dataset.BsmtFinSF1=dataset.BsmtFinSF1.fillna(0.0)

# %%
SaleType={'WD': 0, 'New': 1,'COD': 2,'ConLD': 3,'ConLI': 4,'ConLw': 5,'CWD': 6,'Oth': 7,'Con': 8}
data=[first,second]
for dataset in data:
    dataset['SaleType']=dataset['SaleType'].map(SaleType)

# %%
Condition1={'Norm': 0, 'Feedr': 1, 'Artery': 2, 'RRAn': 3, 'PosN': 4, 'RRAe': 5, 'PosA': 6, 'RRNn': 7, 'RRNe': 8}
data=[first,second]
for dataset in data:
    dataset['Condition1']=dataset['Condition1'].map(Condition1)

# %%
Condition2={'Norm': 0, 'Feedr': 1, 'Artery': 2, 'RRAn': 3, 'PosN': 4, 'RRAe': 5, 'PosA': 6,  'RRAe': 7}
data=[first,second]
for dataset in data:
    dataset['Condition2']=dataset['Condition2'].map(Condition2)

# %%
RoofStyle={'Gable': 0, 'Hip': 1, 'Flat': 2, 'Gambrel': 3, 'Mansard': 4, 'Shed': 5}
data=[first,second]
for dataset in data:
    dataset['RoofStyle']=dataset['RoofStyle'].map(RoofStyle)

# %%
RoofMatl={'CompShg': 0, 'Tar&Grv': 1, 'WdShngl': 2, 'WdShake': 3, 'Metal': 4, 'Membran': 5, 'Roll': 6,  'ClyTile': 7}
data=[first,second]
for dataset in data:
    dataset['RoofMatl']=dataset['RoofMatl'].map(RoofMatl)

# %%
Exterior1st={'VinylSd': 0, 'MetalSd': 1,'HdBoard': 2,'Wd Sdng': 3,'Plywood': 4,'CmentBd': 5,'Stucco': 6,'BrkFace': 7, 'AsbShng': 8, 'ImStucc': 9, 'BrkComm': 11, 'Stone': 12, 'AsphShn': 13, 'CBlock': 14}
data=[first,second]
for dataset in data:
    dataset['Exterior1st']=dataset['Exterior1st'].map(Exterior1st)

# %%
Exterior2nd={'VinylSd': 0, 'MetalSd': 1,'HdBoard': 2,'Wd Sdng': 3,'Plywood': 4,'CmentBd': 5,'Wd Shng': 6,'Stucco': 7,'BrkFace': 8, 'AsbShng': 9, 'ImStucc': 10, 'Brk Cmn': 11, 'Stone': 12, 'AsphShn': 13, 'Other': 14, 'CBlock': 15}
data=[first,second]
for dataset in data:
    dataset['Exterior2nd']=dataset['Exterior2nd'].map(Exterior2nd)

# %%
ExterQual={'TA': 0, 'Gd': 1,'Ex': 2, 'Fa': 3}
data=[first,second]
for dataset in data:
    dataset['ExterQual']=dataset['ExterQual'].map(ExterQual)

# %%
ExterCond={'TA': 0, 'Gd': 1,'Fa': 2,'Ex': 3,'Po': 4}
data=[first,second]
for dataset in data:
    dataset['ExterCond']=dataset['ExterCond'].map(ExterCond)

# %%
Foundation={'PConc': 0, 'CBlock': 1, 'BrkTil': 2, 'Slab': 3, 'Stone': 4, 'Wood': 5}
data=[first,second]
for dataset in data:
    dataset['Foundation']=dataset['Foundation'].map(Foundation)

# %%
BsmtQual={'TA': 0, 'Gd': 1,'Ex': 2, 'Fa': 3}
data=[first,second]
for dataset in data:
    dataset['BsmtQual']=dataset['BsmtQual'].map(BsmtQual)

# %%
BsmtCond={'TA': 0, 'Gd': 1,'Fa': 2, 'Po': 3}
data=[first,second]
for dataset in data:
    dataset['BsmtCond']=dataset['BsmtCond'].map(BsmtCond)

# %%
BsmtExposure={'No': 0, 'Av': 1,'Gd': 2, 'Mn': 3}
data=[first,second]
for dataset in data:
    dataset['BsmtExposure']=dataset['BsmtExposure'].map(BsmtExposure)

# %%
BsmtFinType1={'Unf': 0, 'GLQ': 1, 'ALQ': 2, 'BLQ': 3, 'Rec': 4, 'LWQ': 5}
data=[first,second]
for dataset in data:
    dataset['BsmtFinType1']=dataset['BsmtFinType1'].map(BsmtFinType1)

# %%
BsmtFinType2={'Unf': 0, 'Rec': 1, 'LwQ': 2, 'BLQ': 3, 'ALQ': 4, 'GLQ': 5}
data=[first,second]
for dataset in data:
    dataset['BsmtFinType2']=dataset['BsmtFinType2'].map(BsmtFinType2)

# %%
Heating={'GasA': 0, 'GasW': 1, 'Grav': 2, 'Wall': 3, 'OthW': 4, 'Floor': 5}
data=[first,second]
for dataset in data:
    dataset['Heating']=dataset['Heating'].map(Heating)

# %%
HeatingQC={'Ex': 0, 'TA': 1,'Gd': 2,'Fa': 3,'Po': 4}
data=[first,second]
for dataset in data:
    dataset['HeatingQC']=dataset['HeatingQC'].map(HeatingQC)

# %%
CentralAir={'Y': 0, 'N': 1}
data=[first,second]
for dataset in data:
    dataset['CentralAir']=dataset['CentralAir'].map(CentralAir)

# %%
Electrical={'SBrkr': 0, 'FuseA': 1,'FuseF': 2,'FuseP': 3,'Mix': 4}
data=[first,second]
for dataset in data:
    dataset['Electrical']=dataset['Electrical'].map(Electrical)

# %%
KitchenQual={'TA': 0, 'Gd': 1,'Ex': 2, 'Fa': 3}
data=[first,second]
for dataset in data:
    dataset['KitchenQual']=dataset['KitchenQual'].map(KitchenQual)

# %%
Functional={'Typ': 0, 'Min2': 1, 'Min1': 2, 'Mod': 3, 'Maj1': 4, 'Maj2': 5, 'Sev': 6}
data=[first,second]
for dataset in data:
    dataset['Functional']=dataset['Functional'].map(Functional)

# %%
SaleCondition={'Normal': 0, 'Partial': 1, 'Abnorml': 2, 'Family': 3, 'Alloca': 4, 'AdjLand': 5}
data=[first,second]
for dataset in data:
    dataset['SaleCondition']=dataset['SaleCondition'].map(SaleCondition)

# %%
HouseStyle={'1Story': 0, '2Story': 1, '1.5Fin': 2, 'SLvl': 3, 'SFoyer': 4, '1.5Unf': 5, '2.5Unf': 6,  '2.5Fin': 7}
data=[first,second]
for dataset in data:
    dataset['HouseStyle']=dataset['HouseStyle'].map(HouseStyle)

# %%
BldgType={'1Fam': 0, 'TwnhsE': 1,'Duplex': 2,'Twnhs': 3,'2fmCon': 4}
data=[first,second]
for dataset in data:
    dataset['BldgType']=dataset['BldgType'].map(BldgType)

# %%
PavedDrive={'Y': 0, 'N': 1,'P': 2}
data=[first,second]
for dataset in data:
    dataset['PavedDrive']=dataset['PavedDrive'].map(PavedDrive)

# %%
MSZoning={'RL': 0, 'RM': 1,'FV': 2,'RH': 3,'C (all)': 4}
data=[first,second]
for dataset in data:
    dataset['MSZoning']=dataset['MSZoning'].map(MSZoning)

# %%
Neighborhood={'CollgCr': 0, 'OldTown': 1,'Edwards': 2,'Somerst': 3,'Gilbert': 4,'NridgHt': 5,'Sawyer': 6,'BrkSide': 7,'Crawfor': 8, 'Mitchel': 9, 'NoRidge': 10, 'Timber': 11, 'IDOTRR': 12, 'ClearCr': 13, 'StoneBr': 14, 'SWISU': 15, 'MeadowV': 16, 'Blmngtn': 17, 'BrDale': 18, 'Veenker': 19, 'NPkVill': 20, 'Blueste': 21}
data=[first,second]
for dataset in data:
    dataset['Neighborhood']=dataset['Neighborhood'].map(Neighborhood)

# %%
Street={'Pave': 1,'Grvl': 2}
data=[first,second]
for dataset in data:
    dataset['Street']=dataset['Street'].map(Street)

# %%
MasVnrType={'None': 0, 'BrkFace': 1,'Stone': 2,'BrkCmn': 3}
data=[first,second]
for dataset in data:
    dataset['MasVnrType']=dataset['MasVnrType'].map(MasVnrType)

# %%
LandContour={'Lvl': 0, 'Bnk': 1,'HLS': 2,'Low': 3}
data=[first,second]
for dataset in data:
    dataset['LandContour']=dataset['LandContour'].map(LandContour)

# %%
LandSlope={'Gtl': 0, 'Mod': 1, 'Sev':2}
data=[first,second]
for dataset in data:
    dataset['LandSlope']=dataset['LandSlope'].map(LandSlope)

# %%
LotConfig={'Inside': 0, 'Corner': 1,'CulDSac': 2,'FR2': 3,'FR': 3}
data=[first,second]
for dataset in data:
    dataset['LotConfig']=dataset['LotConfig'].map(LotConfig)

# %%
columns=['LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional']

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
MSZoning
# Out:
# {'RL': 0, 'RM': 1, 'FV': 2, 'RH': 3, 'C (all)': 4}

# %%
first.describe()
# Out:
#                 Id   MSSubClass     MSZoning        LotArea       Street  \
# count  1460.000000  1460.000000  1460.000000    1460.000000  1460.000000
# mean    730.500000    56.897260     0.298630   10516.828082     1.004110
# std     421.610009    42.300571     0.668388    9981.264932     0.063996
# min       1.000000    20.000000     0.000000    1300.000000     1.000000
# 25%     365.750000    20.000000     0.000000    7553.500000     1.000000
# 50%     730.500000    50.000000     0.000000    9478.500000     1.000000
# 75%    1095.250000    70.000000     0.000000   11601.500000     1.000000
# max    1460.000000   190.000000     4.000000  215245.000000     2.000000
#
#        LandContour    LotConfig    LandSlope  Neighborhood   Condition1  ...  \
# count  1460.000000  1456.000000  1460.000000   1103.000000  1460.000000  ...
# mean      0.185616     0.406593     0.062329      5.994560     0.332192  ...
# std       0.606509     0.751309     0.276232      5.197023     1.042578  ...
# ...

# %%
pd.get_dummies(first, prefix=None, prefix_sep='_', dummy_na=False, columns=None, sparse=False, drop_first=False, dtype=None)
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LandContour  LotConfig  \
# 0        1          60         0     8450       1            0        0.0
# 1        2          20         0     9600       1            0        3.0
# 2        3          60         0    11250       1            0        0.0
# 3        4          70         0     9550       1            0        1.0
# 4        5          60         0    14260       1            0        3.0
# ...    ...         ...       ...      ...     ...          ...        ...
# 1455  1456          60         0     7917       1            0        0.0
# 1456  1457          20         0    13175       1            0        0.0
# 1457  1458          70         0     9042       1            0        0.0
# 1458  1459          20         0     9717       1            0        0.0
# 1459  1460          20         0     9937       1            0        0.0
#
#       LandSlope  Neighborhood  Condition1  ...  OpenPorchSF  EnclosedPorch  \
# ...

# %%
x_train = first.drop(['SalePrice','Id'],axis = 1)
y_train = first['SalePrice']

# %%
x_test = second.drop('Id', axis = 1)

# %%
print(first.head())
# Out:
#    Id  MSSubClass  MSZoning  LotArea  Street  LandContour  LotConfig  \
# 0   1          60         0     8450       1            0        0.0
# 1   2          20         0     9600       1            0        3.0
# 2   3          60         0    11250       1            0        0.0
# 3   4          70         0     9550       1            0        1.0
# 4   5          60         0    14260       1            0        3.0
#
#    LandSlope  Neighborhood  Condition1  ...  OpenPorchSF  EnclosedPorch  \
# 0          0           0.0           0  ...           61              0
# 1          0          19.0           1  ...            0              0
# 2          0           0.0           0  ...           42              0
# 3          0           8.0           0  ...           35            272
# 4          0          10.0           0  ...           84              0
#
#    3SsnPorch  ScreenPorch  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
SaleCondition = first['LotArea']
SalePrice = first['SalePrice']
plt.xlabel('SaleCondition')
plt.ylabel('SalePrice')
plt.scatter(SaleCondition,SalePrice,alpha = 0.57)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
# x_train, y_train = first(return_X_y=True)
clf = DecisionTreeRegressor().fit(x_train, y_train)
regressor = DecisionTreeRegressor(random_state=0)
cross_val_score(regressor, x_train, y_train, cv=10)
# Out:
# array([0.6514009 , 0.68922141, 0.80404667, 0.74200084, 0.77043929,
#        0.865021  , 0.82192819, 0.76010208, 0.58901153, 0.76059728])

# %%
#second.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
np.any(np.isnan(second))
# Out:
# False

# %%
np.all(np.isfinite(x_test))
# Out:
# True

# %%
y_pred = clf.predict(x_test)

# %%
print(second.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   int64
#  3   LotArea        1459 non-null   int64
#  4   Street         1459 non-null   int64
#  5   LandContour    1459 non-null   int64
#  6   LotConfig      1459 non-null   float64
#  7   LandSlope      1459 non-null   int64
#  8   Neighborhood   1459 non-null   float64
#  9   Condition1     1459 non-null   int64
#  10  Condition2     1459 non-null   int64
#  11  BldgType       1459 non-null   int64
#  12  HouseStyle     1459 non-null   int64
#  13  OverallQual    1459 non-null   int64
#  14  OverallCond    1459 non-null   int64
#  15  YearBuilt      1459 non-null   int64
#  16  YearRemodAdd   1459 non-null   int64
#  17  RoofStyle      1459 non-null   int64
# ...

# %%
print(y_pred)
# Out:
# [127500. 145000. 192000. ... 145000. 103200. 200000.]

# %%
acc_logistic = clf.score(x_train,y_train)

# %%
print(acc_logistic)
# Out:
# 1.0

# %%
print(cross_val_score(regressor, x_train, y_train, cv=10))
# Out:
# [0.6514009  0.68922141 0.80404667 0.74200084 0.77043929 0.865021
#  0.82192819 0.76010208 0.58901153 0.76059728]

# %%
output = pd.DataFrame({'Id': second.Id, 'SalePrice': y_pred})
output.to_csv('Predection.csv', index=False)
print("Your submission was successfully saved!")
# Out:
# Your submission was successfully saved!
